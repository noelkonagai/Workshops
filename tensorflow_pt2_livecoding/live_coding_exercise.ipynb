# %% [markdown]
# # Live Coding: predicting diabetes
#
# Using this [Kaggle Dataset](https://www.kaggle.com/uciml/pima-indians-diabetes-database/data), try predicting with the highest accuracy rate the occurence of diabetes ('Class'). You can use any model, just aim for improving the prediction accuracy. Below is some code to start with. At the very end run
#
# ```python
# test_metrics = model.evaluate(input_fn = test_input_func,steps=1000)
# print("test metrics: {}".format(test_metrics))
# ```
#
# to get the accuracy.
#
# Here is an explanation of the data, for you to think what columns to cross.
#
#     "       1. Number of times pregnant\n",
#     "       2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test\n",
#     "       3. Diastolic blood pressure (mm Hg)\n",
#     "       4. Triceps skin fold thickness (mm)\n",
#     "       5. 2-Hour serum insulin (mu U/ml)\n",
#     "       6. Body mass index (weight in kg/(height in m)^2)\n",
#     "       7. Diabetes pedigree function\n",
#     "       8. Age (years)\n",
#     "       9. Class variable (0 or 1)\n",

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split as tts
# Out:
# /Users/noelkonagai/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
data = pd.read_csv('pima-indians-diabetes.csv')

##train-test split
train_size = round(len(data) * 0.7)

X = data[data.columns.difference(['Class'])]
Y = data[['Class']]

x_train = X[:train_size]
y_train = Y[:train_size]

x_test = X[train_size:]
y_test = Y[train_size:]

data[:5]
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C
